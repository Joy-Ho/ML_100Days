# %% [markdown]
# # 手刻基本Naive Bayes模型

# %% [markdown]
# #### 學習重點：理解單純貝氏模型原理

# %% [markdown]
# ---

# %%
import re
import numpy as np
import math
import os
import glob
import codecs

from collections import defaultdict
from collections import Counter

def tokenize(message):
    message=message.lower()
    all_words=re.findall("[a-z0-9]+",message)
    return set(all_words)

# %% [markdown]
# ### 讀入資料並分割為 train/testset

# %%
X = []
Y = []
paths =[r'spam_data/spam_data/spam', r'spam_data/spam_data/easy_ham', r'spam_data/spam_data/hard_ham'] 
for path in paths:
    for fn in glob.glob(path+"/*"):
        if "ham" not in fn:
            is_spam = True
        else:
            is_spam = False
        #codecs.open可以避開錯誤，用errors='ignore'
        with codecs.open(fn,encoding='utf-8', errors='ignore') as file:
            for line in file:
                #這個line的開頭為Subject:
                if line.startswith("Subject:"):
                    subject=re.sub(r"^Subject:","",line).strip()
                    X.append(subject)
                    Y.append(is_spam)

# %%
from sklearn.model_selection import train_test_split
# random_state 是為了讓各為學員得到相同的結果，平時可以移除
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
X_test
# Out:
# ['Another low probability event',
#  'Wanna see me get fisted?',
#  "Give Away FREE CD's - Earn $5K in 30 Days!",
#  'Re: Polit-spam',
#  'Making a mesh on the move',
#  'Re: Digital radio playlists are prohibited?!',
#  'Re: [SAtalk] [OT] SpamAssassin figures...',
#  'When an engineer flaps his wings',
#  'Eldred Press Watch',
#  '[Spambayes] deleting "duplicate" spam before training?  good idea',
#  'Never pay for porn again, YOUR FREE PAYSITE is here! 6277zwyL0-111bAgY1254IhZJ0-37-27',
#  'Skateboarder drives-through Subway. With his face',
#  'Testing a system, please delete',
#  'MAKE MONEY GIVING AWAY FREE STUFF!',
#  'Customized Warez CDs',
#  'sylpheed-claws',
#  'Re: New testing packages',
#  'Adult: Free Access',
#  'ADV: Professional Teeth Whitening At Home!                                                   ovcnd',
#  '[Spambayes] understanding high false negative rate',
#  '[zzzzteana] Fw: [nessie] New Nessie Pics',
#  'Blue people of the world unite!',
#  'RE: sed /s/United States/Roman Empire/g',
#  "Gaiman kicks McFarlane's ass in court",
#  "Wrox Press Developer's Journal",
#  'Accessibility watershed?',
#  'Re: Entrepreneurs',
#  'iSilo announcements (August 15, 2002)',
#  'Global crash fears as German bank sinks',
#  'Re: asynchronous I/O (was Re: Gasp!)',
#  '[SAdev] [Bug 886] Add a rule to detect Content-type message/partial',
#  'Re: Exmh && speed',
#  'Re: [zzzzteana] The Coming Firestorm',
#  'Re: [SAtalk] O.T. Habeus -- Why?',
#  'Re: sprint delivers the next big thing??',
#  'Ou Wei Lighting,Nights Will Be Lightening!',
#  'Re: The Wrong Business',
#  'Snub for minister in election row',
#  'Holidays are coming?',
#  'Re: xmms and .mp3 files.',
#  'AmeriCorpsVISTA',
#  'FW: disable some sites',
#  '[Spambayes] testing results',
#  'Re: [ILUG] Redhat 8.0',
#  'the captain has turned off the "no hittin\' it" sign',
#  '[Lockergnome Tech Specialist]  Concrete Geekitude',
#  'enter Chinese market',
#  'At last, I have an excuse',
#  'Reg Headlines Wednesday July 17',
#  'Mac OS X browsers',
#  'What to look for in your next smart phone (Tech Update)',
#  'blogged item',
#  'Re: K3B',
#  '[ILUG] °ӷ~줽ǥX',
#  'Check out the new CLIE PEG-T665C from Sony! (CNET SHOPPER)',
#  'Re: ActiveBuddy',
#  'Re: [SAdev] fully-public corpus of mail available',
#  'Relationship',
#  'Re: [SAtalk] custom score for a given domain?',
#  'Re: Rambus, Man',
#  'Re: boycotting yahoo',
#  'Re: K3B',
#  'Best news yet',
#  'Iran Pushes UN Intervention Against US',
#  'Re: How about subsidizing SSL access to Google?',
#  '[Razor-users] Windows port / bug reports?',
#  '[Spambayes] All but one testing',
#  '[zzzzteana] Fake bank website cons victims',
#  'Re: What a night!',
#  'Do you dream of the latest gadgets? (ZDNET SHOPPER)',
#  'Re: New Sequences Window',
#  '[SAdev] Party in San Francisco tonight',
#  'New Strongbad E-Mail',
#  'Re: [SAdev] phew!',
#  "Ecstasy users 'risk Parkinson's disease'",
#  "Blatantly stolen from a friend's LJ",
#  'Re: Secure Sofware Key',
#  '[Spambayes] spambayes package?',
#  'Re: DataPower announces XML-in-silicon',
#  'Re: The case for spam',
#  'firewalls Digest V1 #33',
#  '[SAtalk] OT: Can Weblogs Reach Ronald Scelson?',
#  'NY Times: "Google\'s automated editors appeared to match the work',
#  '[scoop] Scoop MS Word .doc file into something that plucker or other Palm app can display?',
#  'Re: RedHat 8.0 and his own freetype',
#  '[Spambayes] testing results',
#  '[Lockergnome Tech Specialist]  Transportation Rage',
#  'Private Label Reseller Hosting  -  Expires 9/30/2002',
#  'FreeBSD or Linux for your MySQL Server?',
#  'Reg Headlines Tuesday July 23',
#  'RE: use of base image / delta image for automated recovery from',
#  'Your Gateway to Wealth',
#  'Re: AA Meetings the Hottest Place to Meet Women With Big Bucks',
#  'Reg Headlines Monday July 15',
#  'Brown accused of backtracking on regional museums',
#  'apt-get problem ?',
#  'Linux Gazette #82 (September 2002) available',
#  'Re: latest php upgrade in 7.3',
#  'Teach and Grow Rich',
#  'US forces Israel to lift siege of Arafat',
#  'Education debate',
#  'Patch to enable/disable log',
#  'Re: [SAdev] Re: Web subscription for spamassassin package',
#  '[SAtalk] Huh?',
#  'Re: Zoot apt/openssh & new DVD playing doc',
#  'Re: sed /s/United States/Roman Empire/g',
#  'Re: alsa-driver.spec tweak for homemade kernels',
#  '[Razor-users] Collision of hashes?',
#  'Re: Insert signature',
#  "Second-hand sales blamed for bedbugs' comeback",
#  'Re: The absurdities of life.',
#  'what is the sound of one knee jerking?',
#  'Re: [ILUG] Modem question',
#  'Re: sylpheed-claws',
#  "I'm ready to bare for you!",
#  'Fluxbox',
#  'Linux Gazette #82 (September 2002) available',
#  'Printer Cartridges as low as $1.21 each!',
#  'Fw: some (null) eyecandy packages',
#  'Sam Ruby: "Yup, I\'m a sick puppy." _Me too!_',
#  '[SAtalk] **urgent assistance**',
#  '[Spambayes] understanding high false negative rate',
#  'AOL Keyword: Fraud Probe',
#  'Critical US satellites could be hacked',
#  'REQ: Beast/BSE',
#  'Re: [SAtalk] O.T. Habeus -- Why?',
#  'RE: [ILUG] VPN implementation',
#  'Re: New Sequences Window',
#  'Re: Goodbye Global Warming',
#  'Exmh && speed',
#  '"Hidden tree" the secret of Zen garden',
#  'Space shuttle ready for return',
#  'Re: ALSA (almost) made easy',
#  '[Spambayes] test sets?',
#  'Human handshake opens data stream',
#  'Sun donates elliptic curve code to OpenSSL? (fwd)',
#  'Priceless',
#  'RE: The absurdities of life.',
#  '**** American Millionaire Reveals His Secret Source of Wealth On The Internet!!!',
#  'Re: The 3rd Annual Consult Hyperion Digital Identity Forum',
#  'Re: Secure Sofware Key',
#  'Look What Sandy is Doing in her DORM!!',
#  'Re: ALSA (almost) made easy',
#  'Re: [SAtalk] O.T. Habeus -- Why?',
#  'LP RELEASE: Outrageous military spending',
#  'Re: Exmh && speed',
#  'Re: Slaughter in the Name of God',
#  'Woman finds rubber glove in hamburger bun. Will now sue',
#  'Financial Power You Can Depend On',
#  "Re: Help! I've lost my exmh-unseen window!",
#  '[ILUG] freeserve in the uk?',
#  'NORTON SYSTEMWORKS 2002 CLEARANCE SALE! 6801wbRq4-940mJbj463-19',
#  'MiniNTK 2002-08-16',
#  'Wired: "An urgent business proposition and requests for urgent',
#  "Lindows.com: Michael's Minute: Do the Math...Dispel the Myths",
#  'CAREER OPPORTUNITY.  WORK FROM HOME',
#  'Malcolm in the Middle Sweepstakes Prize Notification',
#  '[Spambayes] Maybe change X-Spam-Disposition to something else...',
#  'Mayan texts reveal superpower wars',
#  '=?iso-2022-jp?B?GyRCRnxLXDhsJE43b0w+IUolNSVWJTglJyUvJUghSyEhJTkbKEI=?=',
#  'Re: Python 2.2 site libs?',
#  'Dan Gillmor responds to Jack Valenti',
#  '[Razor-users] "Can\'t use and undefined value.." error',
#  'Re: The GOv gets tough on Net Users.....er Pirates..',
#  'RE: [SAtalk] 2.41/2.50 spamd/spamc problem',
#  'Do you have a handlebar moustache? Then the Handlebar Club is the',
#  'Funds Investment',
#  'Re: [SAtalk] SA very slow (hangs?) on this message, or is it just me?',
#  'Re: ARRRGHHH Had GPG working, now it doesnt.',
#  'RIP, Robert L Forward',
#  'Teens videotape themselves shooting stapleguns into their arms',
#  'quick hack',
#  'Re: [ILUG] rpm dependencies',
#  'Re: [SAtalk] Still confused about spamd/c',
#  'Re: The Wrong Business',
#  'Re: CVS report',
#  'Re: sed /s/United States/Roman Empire/g',
#  'Re: "Ouch. Ouch. Ouch. Ouch. Ouch...."(was Re: My brain hurts)',
#  'Bush blew take two',
#  'Light reading',
#  'West Nile virus endangers blood transfusions',
#  'Space probe kit will fight terrestrial crime',
#  'Re: Tiny DNS Swap',
#  '=?GB2312?B?NTDUqrvxtcPSu9LazuXHp83yRU1BSUy12Na3tcS7+rvh?=',
#  'Jon Hanna, on the RSS-DEV list, says that RSS, was "not designed',
#  'Re: Insert signature',
#  '^^^^^Cell Phone Belt Clips $1.95^^^^^^                           18070',
#  'RE: Selling Wedded Bliss (was Re: Ouch...)',
#  'Take Advantage of Viral Marketing',
#  'Pb with mplayer-0.90pre7',
#  'Artist Gallery: Troy Paradise',
#  'Re: CVS report',
#  '[use Perl] Headlines for 2002-09-17',
#  'Sun donates elliptic curve code to OpenSSL?',
#  'Re: Electric car an Edsel...',
#  '[use Perl] Headlines for 2002-09-23',
#  'Re: [meta-forkage]',
#  'Dinosaurs Eggs and the Origins of Good and Evil',
#  'Re: use new apt to do null to RH8 upgrade?',
#  'Re: Slaughter in the Name of God',
#  'Re: Java is for kiddies',
#  'Re: Sorting',
#  'Re: sylpheed-claws',
#  'Photoshop this squirrel tuning in, turning on, and dropping out',
#  'NEW TECHNOLOGY - DIGITAL VIDEO RECORDER (Smart IP Technology)',
#  'Re: [SAdev] fully-public corpus of mail available',
#  '[zzzzteana] Bashing the bishop',
#  'Re: PROTECT YOUR COMPUTER AGAINST HARMFUL VIRUSES! 21198',
#  'Re: [zzzzteana] The Cafe Forteana is back online!!!',
#  "Re: Hanson's Sept 11 message in the National Review",
#  'Re: [SAdev] Re: [Razor-users] Mutating spam',
#  "Re: Signers weren't angry young men  (was: Java is for kiddies)",
#  'Re: [SAdev] Integrating SA with Mail::CheckUser ?',
#  'In praise of evolvable formats',
#  'The 3rd Annual Consult Hyperion Digital Identity Forum',
#  '[SAtalk] Compile error under Digital Unix',
#  'Business Proposal.',
#  'RE: [ILUG] doolin',
#  'FORTUNE 500 WORK AT HOME REPS NEEDED!',
#  'NYTimes.com Article: Stop Those Presses! Blonds, It Seems, Will',
#  'Poker for money againts real players',
#  'Re: Sorting',
#  '[Same thread ish] [ILUG] adsl router modem combo',
#  "CNET Cool Gear:  Leica's legendary charm",
#  'Support for Iraq action at new low of 32%',
#  'Re: Java is for kiddies',
#  "America's great misleader",
#  '[use Perl] Headlines for 2002-08-31',
#  'Re: lifegem',
#  'Re: EBusiness Webforms: cluetrain has left the station',
#  'New Solar System body revealed',
#  'Re: storage bits',
#  'Now heavily medicated',
#  'Japanese kids spend a day in school jumping in the swimming pool',
#  'Back to School with Buy4Now',
#  "RE: The Curse of India's Socialism",
#  'Re: [ILUG] Formatting a windows partition from Linux',
#  'Re: [gst-devel] Red Hat 8.0',
#  'Re: RH 8 no DMA for DVD drive',
#  'Re: Anolther sequence related traceback',
#  'Quantum cryptography takes to the skies',
#  'Re: Entrepreneurs',
#  '$14.95 per year for .COM, .BIZ, and .INFO extensions',
#  'Movie Quiz',
#  'Re: The GOv gets tough on Net Users.....er Pirates..',
#  "Re: Hanson's Sept 11 message in the National Review",
#  'From',
#  'Best product for 2002',
#  'NEWS: GNU/DEVELOPMENT... intl orgns take a close look at GNU/Linux',
#  'Hit the Road with CNA',
#  '$250,000... as low as $6.50 per month.             edahx',
#  '[SACVS] CVS: spamassassin configure,1.1.2.1,1.1.2.2',
#  "Great deals on the Summer's hottest MP3 players (CNET SHOPPER)",
#  '[ILUG-Social] re: Guaranteed to lose 10-12 lbs in 30 days 10.148',
#  '[ILUG] cups question',
#  '[Spambayes] Current histograms',
#  'Re: traceback in new exmh',
#  'Conference calls/best quality/$.18 per minute!',
#  'Re: How unlucky can you get?',
#  'Carcooning',
#  '[Razor-users] The -lm 4 blues',
#  'a problem with apt-get',
#  '[SAdev] [Bug 1075] RPM build puts wrong path in the *.cf files',
#  'Re: revocation of grlygrl201@',
#  'Re: Computational Recreations',
#  'Personal Finance: Resolutions You Can Keep',
#  'Re: [gst-devel] Red Hat 8.0',
#  'Membership Renewal',
#  'RE: Re[2]: Selling Wedded Bliss (was Re: Ouch...)',
#  'Re: flavor cystals',
#  '[Spambayes] Deployment',
#  'Re: Pluck and Luck',
#  'Enlightenment',
#  'sed /s/United States/Roman Empire/g',
#  'Creative political speech',
#  '[use Perl] Headlines for 2002-10-02',
#  'Re: Apt problems',
#  "ADV: Interest rates slashed! Don't wait!                                                   xoxun",
#  'Pluck and Luck',
#  'A productive thread',
#  'Shooting from the Hip: An Interview with Hip Tanaka',
#  'Tip of the Day: When trying to kill head lice with rubbing',
#  'fwd:  NORTON SYSTEMWORKS CLEARANCE SALE_ONLY $29.99 7126kyiK0-697yFCQ4277rqZm-24',
#  'Comrade Communism (was Re: Crony Capitalism (was RE: sed',
#  'Re: [Razor-users] Fire.cloudmark.com is having issues',
#  'Cosmic polarisation detected from South Pole',
#  'Mac OS X browsers',
#  'Re: Java is for kiddies',
#  'Congradulate Birthday Boy Putin. Link to send birthday wishes via',
#  '[ILUG-Social] re: how to register one of the new domain extensions',
#  'Monkey or man?',
#  'Re: Java is for kiddies',
#  '[Spambayes] Ditching WordInfo',
#  'Re: alsa-driver.spec tweak for homemade kernels',
#  'Take all your music on the road (ZDNET SHOPPER)',
#  'iiu.taint.org',
#  'Re: Sorting',
#  '[zzzzteana] Latest Iraq-related news',
#  'Re: Recommended Viewing',
#  'RE: liberal defnitions',
#  'Re: Java is for kiddies',
#  'A revolution in the PC world has arrived.          RSIRTR',
#  'RE: CO2 and climate (was RE: Goodbye Global Warming)',
#  'Re: Here is your Free Access',
#  'Re[2]: Selling Wedded Bliss (was Re: Ouch...)',
#  '[SAdev] [Bug 779] rule broken: CORRUPT_MSGID',
#  'Re[2]: [Razor-users] Reducing impact from tons of email',
#  '[SAtalk] Debianized Packages for SA 2.3+',
#  '[Lockergnome Digital Media]  Clever Ritual',
#  'Keeping up with The Sims: Managing Large Scale Game Content',
#  'Earn 100.000$ in one year working at home',
#  "If you're going to turn on an electric pump to remove water from",
#  'Re: Oh ma gawd - funny site of the day...',
#  '[ILUG] re: popular .BIZ and .COM extensions for only $14.95',
#  '[Spambayes] Current histograms',
#  'Re: [VoID] a new low on the personals tip...',
#  'Oracle of Google',
#  'Re: Goodbye Global Warming',
#  '[Lockergnome Penguin Shell]  Karaoke Kernel',
#  'Re: SYSTEMWORKS CLEARANCE SALE_LIMITED QUANTITIES_ONLY $29.99 TJ',
#  'Re[2]: The absurdities of life.',
#  'Duct-tapers -- suspension and bondage fetish goes mainstream',
#  'Re: AA Meetings the Hottest Place to Meet Women With Big Bucks',
#  '[ILUG] Re: Sun Solaris',
#  'Re: Bindings problem with current CVS code',
#  "Re: problems with 'apt-get -f install'",
#  'Re: New Sequences Window',
#  'Re: Java is for kiddies',
#  'Re: [SAdev] 2.40: ready for release? *NO*',
#  'Tate unveils its biggest work',
#  '[CYBERIA] [Final CfP]: Int. J. on IT Standards Research',
#  'Re: Entrepreneurs',
#  'Parallels',
#  'Ashfield Online 9/1/2002 by Aric McKeown',
#  'What you need for iPaq wireless connectivity (Tech Update)',
#  '[Razor-users] Forged email address',
#  '[SAtalk] Test spam',
#  'Your Daily Dilbert 07/10/2002',
#  'xine src packge still gives errors',
#  'CAUCE NEWS, Vol 6, No 2, June 2002',
#  'Hottest babes!                                                       4139YAEk3--9',
#  'Re: [SAtalk] test',
#  'Re: http://apt.nixia.no/',
#  'I mean why not',
#  'Re: [Razor-users] log problem',
#  '[EVENT NOTIFICATION] UUnet North American Backbone Problems',
#  '[ILUG] Sun Solaris..',
#  "DayTips' Poem-a-Day: 09/13/02",
#  'Re: boycotting yahoo',
#  'Re: [ILUG] Interesting article on free software licences',
#  'OT: RE: [ILUG] Newby to Linux looking for information on cvs',
#  '[ILUG-Social] Re: Important - reenactor insurance needed',
#  'Pics for you',
#  'Re: liberal defnitions',
#  'Forged documents, public drinking, massive fistfights... Who knew',
#  'EIN News - FREE Trial',
#  'Re: apt and a hybrid system',
#  'Re: [SAtalk] Getting yourself removed from spam lists',
#  'Re: sed /s/United States/Roman Empire/g',
#  "Canadians are knockin' boots less, or just not getting any",
#  'RE: [ILUG] cheap linux PCs',
#  'Man kills self with home booby-traps',
#  'Re[6]: A moment of silence for the First Amendment (fwd)',
#  'New, easy to use web conferencing software',
#  'How would you like to create your own DVD library? 4863d-5',
#  'Re: [SAtalk] Too funny',
#  'Online Doctors will fill your Viagra Prescription Now!!!                QEEB',
#  '[use Perl] Stories for 2002-10-09',
#  'Re: DataPower announces XML-in-silicon',
#  'Make a Fortune On eBay                         24772',
#  'Brown budget plans in disarray',
#  'Re: Insert signature',
#  'Re: [ILUG] Email list management howto',
#  'Re: ALSA (almost) made easy',
#  'RE: The Big Jump',
#  'Dawn raids stoke fires of resentment',
#  'Mystery Indian virus heading for Europe',
#  'This Weeks Movie Trivia Question from All Things New England',
#  'RE: [zzzzteana] Moon over ocean',
#  'Bin Laden is still alive, reveals spy phone satellite',
#  'Attn: NORTON SYSTEMWORKS CLEARANCE SALE_ONLY $29.99!                  Y',
#  'Re: /home/dude',
#  'Get the Child Support You Deserve                      10.124',
#  'Senators threaten to rein in Bush',
#  'plate tectonics update',
#  "Laura Bush's 419 letter",
#  'Sourceforge sells out',
#  'Re: Sorting',
#  'Invite: Content Management Summit, Oct. 10th New York City',
#  'CNET NEWS.CONTEXT: Hollywood & Silicon Valley: A way out?',
#  'Re: Goodbye Global Warming',
#  "Friends don't let friends swim drunk. Paging Dr. Darwin..",
#  'This week: Browse or bust',
#  'Welcome, Danny and Quinn!',
#  'Re: ALSA (almost) made easy',
#  'Re: [ILUG] Sun Solaris..',
#  'Another low probability event',
#  '8 Free Movie Tickets for doing a 2 Minute survey! Any Movie, Any Theater!',
#  '[zzzzteana] Language problems',
#  'liberal defnitions',
#  "Re: Hanson's Sept 11 message in the National Review",
#  'why is decentralization worth worrying about?',
#  'NEWS.COM INVESTOR: Techs rise, but Dow falls on day of Bush speech',
#  'Am I This Or Not?',
#  'RE: Liberalism in America',
#  'New Stock Pick: BBAN - Last Pick UP 309%.......................................... gsg',
#  'Re: The MIME information you requested (last changed 3154 Feb 14)',
#  'EFnet #fork',
#  '2000+ year old Greek computer reinterpreted',
#  'CSS and mobile devices',
#  'Re: [ILUG] mini-itx',
#  'Friend,Instantly Copy ANY DVD or Playstation Game with this software......',
#  "Kevin Mitnick's laptop, signed by Woz, on eBay",
#  "Re: Hanson's Sept 11 message in the National Review",
#  'Internet News Feeds for Executives dfvht',
#  'TGE: Thugs of South Boston and The Revenge of the Bandit Princess',
#  '10 die as Israeli helicopter fires on Palestinian crowd',
#  "Major's shame over affair leaves Currie indignant",
#  'The Government Grants You $25,000!',
#  'Re: [SAtalk] SpamAssassin v2.40 released (finally)!',
#  'Ed Cone: "I told my grandmother goodbye."',
#  '=?big5?Q?re:=B7Q=ADn=ADP=B4I,=A7A=C1=D9=ADn=B5=A5=A6h=A4[?=',
#  'Apple Switch parodies',
#  'kitty wants to play "eat your head"',
#  'traceback in new exmh',
#  'ADV: Are you protected? Free Life Insurance quote oefik',
#  '[SAtalk] Running SA as a user app?',
#  'Re: Your bank account',
#  'RE: [ILUG] [OT] Dell machine giving me hassle.',
#  'Competitive Mortgage Rates',
#  '[SAdev] [Bug 839] mailbox corruption not fixed with procmail 3.22',
#  'Outsourcing Reality: Integrating a Commercial Physics Engine',
#  'CNET NEWS.COM: The tech side of homeland defense',
#  'Monster molecule techniques win Chemistry Nobel',
#  'InfoWorld profile of Max Levchin',
#  '[Spambayes] Deployment',
#  'EFFector 15.28: Motions Filed in Morpheus Peer-to-Peer Case,',
#  'Re: ALSA (almost) made easy',
#  '[Spambayes] test sets?',
#  'Scientists prove that shoe size and penis size are not linked.',
#  'Re: ALSA (almost) made easy',
#  'Re: Entrepreneurs',
#  'The "other" kind of work-experience ...',
#  'Place Your LTC Declines with Us',
#  'Musharraf keeps his hands on the reins',
#  'Re: AA Meetings the Hottest Place to Meet Women With Big Bucks',
#  'Re: Optical analog computing?',
#  '[IMG: http://www.joelonsoftware.com/pictures/dhtml2d.jpg (Dynamic',
#  '.Message report from your contact page....//ytu855 rkq',
#  '[SACVS] CVS: spamassassin/debian spamassassin.README.Debian,1.1,1.2',
#  '[Razor-users] Bug ... still',
#  'Mathematics film-festival in October in Berkeley',
#  'WARNING: Your computer may contain a virus!',
#  'Paul Everitt: Interop in the Bazaar.',
#  'RE: [SAtalk] 2.41/2.50 spamd/spamc problem',
#  'Re: [ILUG] find the biggest file',
#  'Re[2]: So I missed this one...',
#  'RE: Java is for kiddies',
#  'Yoga & Painfree Bliss',
#  '[ILUG-Social] Lose 22.5lbs in 3 weeks!',
#  '[ILUG] Guaranteed to lose 10-12 lbs in 30 days 10.206',
#  'Japa-crappers get high-tech',
#  '[Spambayes] Current histograms',
#  '[Lockergnome Webmaster Weekly]  Compatible Whistles',
#  "Save $100's, maybe $1,000's with No Lender's Fees. Click here!",
#  'Why marching is crucial',
#  'Re: [SAtalk] Badly Formatted Spam Report in HTML spam',
#  'RE: Java is for kiddies',
#  'Re: Recommended Viewing',
#  'Re: Working My_Mark2CurSeen',
#  '[WM] GREEN CARD CEKLS  KACIRMAYIN',
#  '=?ISO-2022-JP?B?GyRCTCQ+NUJ6OS05cCIoPF5HLiEqPVAycSQkJE45LT5sGyhC?=',
#  'Teen dies of starvation after stepfather puts him on a bus and',
#  'Shelley Powers raises some interesting questions re whether RDF',
#  'Your Daily Dilbert 07/12/2002',
#  'Re: erratum [Re: no matter ...] & errors',
#  'Get your own fountain of youth! HGH human growth hormone from 21st Century!17441',
#  "Month by month, 'Most Beautiful Man' winners and their galleries. sfw",
#  '=?big5?Q?=A7A=B7=C7=B3=C6=A6n=A4F=B6=DC=3F?=',
#  'Big Five record companies guilty of price fixing',
#  'Re: [SAdev] 2.40: ready for release?',
#  'RE: Recommended Viewing',
#  'How many "inches" do you need to satisfy a woman in bed?',
#  'public mailing list sign up package',
#  'Re: Wifi query',
#  'EFFector 15.24: EFF Submits Comments to FCC, Johansen Trial',
#  '[Spambayes] timtest broke?',
#  'Geocaching.com Weekly Cache Notification',
#  '[SAtalk] SA CGI Configurator Scripts',
#  'Re: Ringing bell on other computer',
#  'Are bigger notebooks better?',
#  'Get a FREE Bottle of Wine & Tasting Kit',
#  'New Freeware Download',
#  'Re: Avast there matey',
#  'Re: The case for spam',
#  'Re: Snow',
#  'Four Ways to Use Symbols to Add Emotional Depth to Games',
#  'Re: A moment of silence for the First Amendment (fwd)',
#  '[SAtalk] Re: Custom actions for high scoring spam',
#  'Re: lifegem',
#  'If you like graphic novels/comics',
#  'New testing packages',
#  "Re: Signers weren't angry young men  (was: Java is for kiddies)",
#  'Re: Avast there matey',
#  'Re: bad focus/click behaviours',
#  '[zzzzteana] SETI at Home',
#  'Critical breast cancer gene identified',
#  'Re: Electric car an Edsel...',
#  'Re: Entrepreneurs',
#  'Get your own genome, feed your hypochondria',
#  'SPS se odrekao Slobodana Milosevica',
#  'Cat shot through eye with horse dart tranquilizer roams',
#  'Re: The risks of client systems writing to server registry',
#  'Re: Java is for kiddies',
#  'HELP WANTED.  WORK FROM HOME REPS.',
#  'whoa',
#  'Anolther sequence related traceback',
#  'Iowa: "There was frost outside this morning!"',
#  'Amorous ostriches scoop Ig Nobel prize',
#  'bigtwo: coffee.marilith.1 released',
#  'RE: Goodbye Global Warming',
#  '[IRR] [dgc.chat] First public release of NeuDist Distributed',
#  "Virgin's latest airliner.",
#  'Re: Wifi query',
#  "Perl.  It's just a language.",
#  'Re: Problem building lame-3.92-fr5.src.rpm on RH8',
#  '[SAdev] [Bug 828] spamassassin.org is unreliable',
#  '$15,000 umbrella stand: nothing exceeds like excess',
#  'West Coast port closures may cancel Christmas.',
#  "Robbie's 80m deal puts EMI on new path",
#  '[ILUG] Do NOT Drop your Life Insurance',
#  'Re: Selling Wedded Bliss (was Re: Ouch...)',
#  'Re: the underground software vulnerability marketplace and its',
#  'Bush blew take two',
#  'Re: storage bits',
#  'Bush Covers the Waterfront',
#  'Our Dumb Pipeline',
#  "The Ozone Hole is getting smaller... But Leroy's Getting LARRRRRGER",
#  'Re: [ILUG] directory merging',
#  'Turning junk computers into activist gold',
#  'RE: liberal defnitions',
#  'Re: ActiveBuddy',
#  'A couple of nits...',
#  'Re: ALSA (almost) made easy',
#  'people we know on the web',
#  'RE: MIT OpenCourseWare',
#  'Penile enlargement method - guaranteed !',
#  'Re: [Razor-users] Fire.cloudmark.com is having issues',
#  'Re: "Holiday Season" 2002 begins',
#  'Re[2]: Selling Wedded Bliss (was Re: Ouch...)',
#  "Re: Hi! I'm new here.",
#  'Re: Re[3]: Selling Wedded Bliss (was Re: Ouch...)',
#  'Re: Sorting',
#  "On Windley's Radar Too",
#  'Z-app the Competition with Roster',
#  "What's facing FBI's new CIO? (Tech Update)",
#  'Unseen window versus Sequences Window',
#  'Re: [ILUG] Newbie seeks advice - Suse 7.2',
#  '[Spambayes] Maybe change X-Spam-Disposition to something else...',
#  'RE: [SAtalk] O.T. Habeus -- Why?',
#  'Re: lifegem',
#  'Re: sed /s/United States/Roman Empire/g',
#  'Re: Alsa/Redhat 8 compatability',
#  'Problem building lame-3.92-fr5.src.rpm on RH8',
#  'Re: Goodbye Global Warming',
#  '[SAtalk] Razor problem',
#  'Police pay damages to journalist',
#  'sed /s/United States/Roman Empire/g',
#  'A Living Memorial',
#  'Re: [SAtalk] O.T. Habeus -- Why?',
#  'apt-get http fails',
#  'Hype is all for tired old Panorama',
#  'problems with apt update',
#  '[ILUG] Newbie seeks advice - Suse 7.2',
#  '[use Perl] Headlines for 2002-09-26',
#  'TV democracy in action',
#  'Never pay eBay listing fees again!',
#  'Re: use new apt to do null to RH8 upgrade?',
#  'Man finds lost marbles after 70 years....',
#  '[Spambayes] test sets?',
#  'Think before you leap, man flies powered parachute into',
#  'Re: Canadians',
#  'Re: sed /s/United States/Roman Empire/g',
#  'alsa-driver.spec tweak for homemade kernels',
#  'GOVERNMENT REGULATION IS KILLING THE STOCK MARKET',
#  'Bank robber gets the loot, makes it out of bank, shoots self in',
#  '[SAdev] [Bug 1075] RPM build puts wrong path in the *.cf files',
#  'Marriage makes both sexes happy',
#  'Plans for new youth units blocked',
#  'Re[2]: AA Meetings the Hottest Place to Meet Women With Big Bucks',
#  'If You Dont... Your Competition Will!              7377',
#  'Daniel Berlinger has noticed that Mac software shops are starting',
#  'Re: ALSA (almost) made easy',
#  'Re: Insert signature',
#  'Viruses that also hack computers on the rise',
#  'Re: xmms and .mp3 files.',
#  'Guaranteed to lose 10-12 lbs in 30 days                          11.150',
#  'Speaking in Texas this Friday',
#  're: domain registration savings',
#  'Re: ALSA (almost) made easy',
#  'Re: [zzzzteana] Which Muppet Are You?',
#  'Attn: NORTON SYSTEMWORKS 2002 BLOWOUT!                 QHZHC',
#  '[Spambayes] test sets?',
#  '[use Perl] Stories for 2002-09-06',
#  'FW: Bush blew take two',
#  'Re: EBusiness Webforms: cluetrain has left the station',
#  'How I made Edwina tell all',
#  'RE: sprint delivers the next big thing??',
#  'Peruvian congressman has challenged his Vice President to a duel.',
#  'Doom 3',
#  '[Spambayes] Deployment',
#  'Your Shipment Status',
#  'Re: [SAdev] 2.40: ready for release? *NO*',
#  '[ILUG] Best Replica Goods - Best Prices',
#  'Note to self: Read the pingback spec. Form opinion.',
#  'How the other half gives',
#  '[zzzzteana] re: Steam',
#  "'I am an enemy of your country'",
#  'Re: The Wrong Business',
#  '[SAtalk] help with postfix + spamassassin',
#  'Re: [Razor-users] Collision of hashes?',
#  'Go-ahead for new-style hospitals',
#  'Re: [ILUG] Looking for a file / directory in zip file',
#  'Meet Carol Ann Duffy',
#  'Re: Selling Wedded Bliss (was Re: Ouch...)',
#  'Re: New Sequences Window',
#  '[Spambayes] Deployment',
#  "Re: Hanson's Sept 11 message in the National Review",
#  '[zzzzteana] Lincs lizard',
#  'Five',
#  'Quick, Outlaw Touching',
#  'Ray Ozzie: Software Platform Dynamics.',
#  'Re: A moment of silence for the First Amendment & Angry Liberal Yutes',
#  'Colophon 2',
#  'RE: AA Meetings the Hottest Place to Meet Women With Big Bucks',
#  'Re: [zzzzteana] Which Muppet Are You?',
#  '[SAdev] [Bug 1052] bondedsender.com is a scam',
#  'Personalize your Palm OS device',
#  "SF Weekly's Ultimate SF Date lineup :-)",
#  'Re: DataPower announces XML-in-silicon',
#  'Re: The absurdities of life.',
#  'Re: Oh ma gawd - funny site of the day...',
#  'Curried radiation burns',
#  '[SAtalk] RBL timed oiut and Spam Assassin killed',
#  'JavaServer Pages updated',
#  'F2M - Ihre kostenlose Faxnummer - Newsletter',
#  'Re: dylsexics of the wrold, untie!',
#  'Re: [Razor-users] early experiences with Razor2 (and SA)',
#  'Re: Java is for kiddies',
#  'Re: CVS report',
#  'Re: Please help a newbie compile mplayer :-)',
#  'Re: New Sequences Window',
#  'Blair apologises for exam fiasco',
#  '[Lockergnome Penguin Shell]  Good Hearts',
#  'Conversations From GDC Europe: Bill Fulton, Zeno Colaco, Harvey Smith',
#  "[SAdev] [Bug 1006] Spamassassin's build process makes packaging",
#  'Liddle quits Today with new BBC deal',
#  'Goats with enormous testicles, and a life-sized cow sculpted from',
#  'MULTIPLY YOUR CUSTOMER BASE!',
#  '[use Perl] Stories for 2002-10-08',
#  'Re: [Razor-users] Razor with sendmail',
#  'use new apt to do null to RH8 upgrade?',
#  'Re: [ILUG] Seconds to date?',
#  'Re: Random hack Q: drawing on CDs with lasers?',
#  'Market Internet Access - No Investment Needed',
#  'Re: How unlucky can you get?',
#  'Double Your Life Insurance at NO EXTRA COST!...               TCTOOM',
#  'Re: alsa-driver rebuild fails with undeclared USB symbol',
#  '[use Perl] Stories for 2002-10-08',
#  '[Razor-users] honor is not in csl',
#  'Re: Sorting',
#  'Re: [SAtalk] 2.42: est release?',
#  'World Wide Words -- 17 Aug 02',
#  '[use Perl] Stories for 2002-08-27',
#  "Food 'cancer chemical' reaction identified",
#  'AOL Keyword: Fraud Probe',
#  'I NEED AN URGENT CAPABLE ASSISTANCE.TEL:+225 05775748',
#  'The Analyst Primer',
#  '[IRR] The 3rd Annual Consult Hyperion Digital Identity Forum',
#  'Re: [SAtalk] O.T. Habeus -- Why?',
#  "Gillmor: Apple's fair-use friendly OS?",
#  'UFOs in the Sky!',
#  'Senate Committee Passes Nanotech Bill',
#  'Detective sends out Al Qaeda warning based on Onion story',
#  "Steven Levy's wireless neighbors"]

# %%
train_data = []
test_data = []

for x_, y_ in zip(X_train, y_train):
    train_data.append([x_, y_])

for x_, y_ in zip(X_test, y_test):
    test_data.append([x_, y_])

# %% [markdown]
# ---

# %% [markdown]
# ### defaultdict用法示範

# %%
from collections import defaultdict

mess='This is our first time in Taiwan,,,,, such a beautiful contury'

counts=defaultdict(lambda:[0,0])
counts['you'][0]+=1
counts['hi'][0]+=1
counts['hi'][1]+=2
counts['no'][1]+=1
counts['no'][0]+=8
print('dic : {}'.format(counts))
print('you : {}'.format(counts['you']))
# Out:
# dic : defaultdict(<function <lambda> at 0x1a1e7dff80>, {'you': [1, 0], 'hi': [1, 2], 'no': [8, 1]})
# you : [1, 0]

# %% [markdown]
# ### 創造一個字典，裡面是{'hi': [1, 0]}，對應第一個數字是是垃圾郵件的次數，對應第二個數字是不是垃圾郵件的次數

# %%
def count_words(training_set):
    counts=defaultdict(lambda:[0,0])
    for message,is_spam in training_set:
        for word in tokenize(message):
            '''自行填入， list[0]為出現在spam中的次數，list[1]為出現在ham(非spam)中的次數'''
    return counts

# %% [markdown]
# ---

# %% [markdown]
# ## 計算 p(w|spam) / p(w|non_spam)
# * 其中K為超參數，為了確保分母/分子皆不為0

# %%
def word_probabilities(counts,total_spams,total_non_spams,k=0.5):
    #獲得三組數據，分別為w這個字，p(w|spam)，p(w|non_spam)
    #counts[w][0]=spam,counts[w][1]=non_spam
    return [(w,("自行填入"+k)/("自行填入"+2*k),("自行填入"+k)/("自行填入"+2*k)) for w in counts]

# %% [markdown]
# ---

# %% [markdown]
# ## 計算貝氏結果

# %%
def spam_probability(word_probs,message, is_spam_probability, is_not_spam_probability):
    #先把這個mail的文字處理一下
    message_words=tokenize(message)
    #初始化值
    log_prob_if_spam=log_prob_if_not_spam=0.0
    #將w這個字，p(w|spam)，p(w|non_spam)依序引入
    for word,prob_if_spam,prob_if_not_spam in word_probs:
        if word in message_words:
            #假如這個字有在這個mail中出現
            #把他的p(w|spam)轉log值加上log_prob_if_spam
            log_prob_if_spam="自行填入"
            #把他的p(w|non_spam)轉log值加上log_prob_if_not_spam
            log_prob_if_not_spam="自行填入"
        else:
            #如果沒出現log_prob_if_spam➕上得值就是1-p(w|spam)也就是這封信是垃圾郵件但是w這個字卻沒在裡面
            log_prob_if_spam=log_prob_if_spam+math.log(1-prob_if_spam)
            log_prob_if_not_spam=log_prob_if_not_spam+math.log(1-prob_if_not_spam)
    log_prob_if_spam = log_prob_if_spam + "自行填入"
    log_prob_if_not_spam = log_prob_if_not_spam + "自行填入"
    
    #把+起來的值轉成exp再算NaiveBayes
    prob_if_spam="自行填入"
    prob_if_not_spam="自行填入"
    #貝氏
    return prob_if_spam/(prob_if_spam+prob_if_not_spam)

# %% [markdown]
# ---

# %% [markdown]
# ### 打包整個模型

# %%
class NaiveBayesClassifier:
    def __init__(self,k=0.5):
        self.k=k
        self.word_probs=[]
    def train(self,training_set):
        #訓練的資料格式為(message,is_spam)
        #所有垃圾郵件的數量
        num_spams=len([is_spam for message,is_spam in training_set if is_spam])
        #所有不是垃圾郵件的數量
        num_non_spams=len(training_set)-num_spams
        
        self.is_spam_probability = "自行填入"
        self.is_not_spam_probability = "自行填入"
        #把training_set裡面的所有字體轉成('Bad',num_is_spam,num_not_spam)
        word_counts=count_words(training_set)
        self.word_probs=word_probabilities(word_counts,num_spams,num_non_spams,self.k)
    def classify(self,message):
        return spam_probability(self.word_probs,message, self.is_spam_probability, self.is_not_spam_probability)

# %% [markdown]
# ---

# %% [markdown]
# ### Fit 訓練集

# %%
classifier=NaiveBayesClassifier()

# %%
classifier.train(train_data)

# %% [markdown]
# ### 預測

# %%
classified=[(subject,is_spam,classifier.classify(subject)) for subject,is_spam in test_data]
counts=Counter((is_spam,spam_probability>0.5) for _,is_spam,spam_probability in classified)

# %%
counts
# Out:
# Counter({(False, False): 578,
#          (True, True): 57,
#          (False, True): 9,
#          (True, False): 41})

# %%
precision=counts[(True, True)]/(counts[(True, True)]+counts[(False, True)])
recall=counts[(True, True)]/(counts[(True, True)]+counts[(True, False)])
binary_accuracy = (counts[(True, True)]+counts[(False, False)])/(counts[(False, True)]+counts[(False, False)]+counts[(True, True)]+counts[(True, False)])
print('accuracy : {:.2f}%'.format(binary_accuracy*100))
print('precision : {:.2f}%'.format(precision*100))
print('recall : {:.2f}%'.format(recall*100))
# Out:
# accuracy : 92.70%
# precision : 86.36%
# recall : 58.16%
